# %% [markdown]
# # Exercise: Geographical Cluster Analysis of Taxi Rides
# Using the NY Taxi data set (see Use Case Block I) and the use case from the lecture...

# %%
import pandas as pd
import numpy as np
import folium

# %%
#check if notebook runs in colab
import sys
IN_COLAB = 'google.colab' in sys.modules
print('running in Colab:',IN_COLAB)
path='..'
if IN_COLAB:
  #in colab, we need to clone the data from the repo
  # !git clone https://github.com/keuperj/DataScienceSS20.git
  path='DataScienceSS20'
# Out:
# running in Colab: False

# %%
# we load the data we have saved after wrangling and pre-processing in block I
train=pd.read_csv(path+'/DATA/train_cleaned.csv')

# %%
#select only the culumns with the ride coordinates
coordinates = train[ ['pickup_latitude','pickup_longitude','dropoff_latitude' , 'dropoff_longitude' ] ]

# %% [markdown]
# ## Clustering approach from the lecture
# we will be using simple K-Means:
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
from sklearn.cluster import KMeans

# %%
#define number of clusters and create instance
clusters=100
myKMeans=KMeans(n_clusters=clusters, n_jobs=-1)#parallelize to all cores

# %%
#train model
myKMeans.fit(coordinates.to_numpy()[:100000,:])#use only subset of the data to make it faster
coordinates = coordinates.to_numpy()[:100000,:]

# %%
#get cluster centers
centers=myKMeans.cluster_centers_

# %%
#draw map: green: start, red: end
cluster_map = folium.Map(location = [40.730610,-73.935242],zoom_start = 12,)
for i in range(clusters):
    folium.CircleMarker([centers[i,0], centers[i,1]], radius=3,                
                        color="green", 
                        fill_opacity=0.9
                       ).add_to(cluster_map)
    folium.CircleMarker([centers[i,2], centers[i,3]], radius=3,                
                        color="red", 
                        fill_opacity=0.9
                       ).add_to(cluster_map)
    folium.PolyLine([ [centers[i,0],centers[i,1]] , [centers[i,2],centers[i,3]]  ], color="black", weight=2.5, opacity=1).add_to(cluster_map)

# %%
cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Exercise 1
# Write a function ```show_cluster(cluster_number,...)``` that draws the cluster centers and all start and end points of a given cluster in the map.
# * use the ```predict()``` method to map all data in ```train_data``` to a cluster center
# * use ```folium.CircleMarker``` to draw all members of a given cluster

# %%
def show_cluster(cluster_number):
        #print("ClusterSize: ", np.count_nonzero(myKMeans.labels_ == cluster_number))
        clusterCoords = coordinates[myKMeans.labels_ == cluster_number]
        for i in range(np.count_nonzero(myKMeans.labels_ == cluster_number)):
            folium.CircleMarker([clusterCoords[i,0],clusterCoords[i,1]],radius = 2, color="green",fill_opacity=0.9).add_to(mymap)
            folium.CircleMarker([clusterCoords[i,2],clusterCoords[i,3]],radius = 2, color="red",fill_opacity=0.9).add_to(mymap)

# %%
mymap = folium.Map(location = [40.730610,-73.935242],zoom_start = 12,)
#a = myKMeans.labels_ == 3
#b = coordinates[a]
#print("length: ", np.count_nonzero(myKMeans.labels_ == 3))
#print(myKMeans.labels_.size)
#coordinates[0:10]

# %%
#show_cluster()
show_cluster(41)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Exercise 2
# Write a function ```cluster_var(cluster_number,...)``` that computes the intra- and extra cluster variance for a given cluster. Apply it to all clusters and compare the results for k=100 and k=10.

# %%
dif = np.zeros(100)
def cluster_var(cluster_number):
    clusterCoords = coordinates[myKMeans.labels_ == cluster_number]
    otherCoords = coordinates[myKMeans.labels_ != cluster_number]
    intra_var = clusterCoords.var()
    extra_var = otherCoords.var()
    print("intra varianz of cluster",cluster_number, ':',intra_var)
    print("extra varianz of cluster",cluster_number, ':',extra_var)
    dif[i] = extra_var - intra_var
    
for i in range(100):
    cluster_var(i)
#clusterCoords[0:10]
# Out:
# intra varianz of cluster 0 : 3291.890889083145
# extra varianz of cluster 0 : 3290.477374986586
# extra varianz of cluster 36 : 3290.498312319205
# intra varianz of cluster 37 : 3277.811408778314
# extra varianz of cluster 37 : 3290.523639455803
# intra varianz of cluster 38 : 3288.209950373275
# extra varianz of cluster 38 : 3290.511027007776
# intra varianz of cluster 39 : 3286.6211387581366
# extra varianz of cluster 39 : 3290.514787397274
# intra varianz of cluster 40 : 3288.8553000889315
# extra varianz of cluster 40 : 3290.5216040901005
# intra varianz of cluster 41 : 3303.746182824196
# extra varianz of cluster 41 : 3290.5052417127386
# intra varianz of cluster 42 : 3294.7783476553554
# extra varianz of cluster 42 : 3290.505099966423
# intra varianz of cluster 43 : 3325.7770939852367
# extra varianz of cluster 43 : 3290.506564061228
# intra varianz of cluster 44 : 3290.5639500180496
# extra varianz of cluster 44 : 3290.507349753142
# intra varianz of cluster 45 : 3278.160877675124
# extra varianz of cluster 45 : 3290.522211536344
# intra varianz of cluster 46 : 3291.276430171159
# extra varianz of cluster 46 : 3290.5061406355976
# intra varianz of cluster 47 : 3288.7148685543066
# extra varianz of cluster 47 : 3290.524299542691
# intra varianz of cluster 48 : 3292.0445562604586
# extra varianz of cluster 48 : 3290.4789893909388
# intra varianz of cluster 49 : 3292.7803817242416
# extra varianz of cluster 49 : 3290.5071233493145
# intra varianz of cluster 50 : 3291.57443586893
# extra varianz of cluster 50 : 3290.479828152041
# intra varianz of cluster 51 : 3282.413282339426
# extra varianz of cluster 51 : 3290.5542709159936
# intra varianz of cluster 52 : 3290.5405046038572
# extra varianz of cluster 52 : 3290.50718735629
# intra varianz of cluster 53 : 3291.4917077010155
# extra varianz of cluster 53 : 3290.480660212039
# intra varianz of cluster 54 : 3291.671145743553
# extra varianz of cluster 54 : 3290.4911476395982
# intra varianz of cluster 55 : 3291.3266799608564
# extra varianz of cluster 55 : 3290.5025563811096
# intra varianz of cluster 56 : 3290.742976884572
# extra varianz of cluster 56 : 3290.5035777501084
# intra varianz of cluster 57 : 3290.772894858189
# extra varianz of cluster 57 : 3290.4992733061904
# intra varianz of cluster 58 : 3289.3676173203867
# extra varianz of cluster 58 : 3290.514411963543
# intra varianz of cluster 59 : 3316.9215835352416
# extra varianz of cluster 59 : 3290.5073604728527
# intra varianz of cluster 60 : 3292.4588985279547
# extra varianz of cluster 60 : 3290.4943135361573
# intra varianz of cluster 61 : 3286.0318762614475
# extra varianz of cluster 61 : 3290.5193361461065
# intra varianz of cluster 62 : 3286.7618652802385
# extra varianz of cluster 62 : 3290.5269396121826
# intra varianz of cluster 63 : 3291.2939423072294
# extra varianz of cluster 63 : 3290.487993334839
# intra varianz of cluster 64 : 3290.669527937585
# extra varianz of cluster 64 : 3290.502840059651
# intra varianz of cluster 65 : 3291.6256961174163
# extra varianz of cluster 65 : 3290.4945947260767
# intra varianz of cluster 66 : 3285.104578299356
# extra varianz of cluster 66 : 3290.5112457255304
# intra varianz of cluster 67 : 3291.089225423505
# extra varianz of cluster 67 : 3290.493432301046
# intra varianz of cluster 68 : 3291.307752599279
# extra varianz of cluster 68 : 3290.4920604426884
# intra varianz of cluster 69 : 3288.9817843976166
# extra varianz of cluster 69 : 3290.5084749337266
# intra varianz of cluster 70 : 3292.3100375934105
# extra varianz of cluster 70 : 3290.489744613986
# intra varianz of cluster 71 : 3282.009254340823
# extra varianz of cluster 71 : 3290.5259358369412
# intra varianz of cluster 72 : 3289.0505392318987
# extra varianz of cluster 72 : 3290.514005658915
# intra varianz of cluster 73 : 3288.6342782580346
# extra varianz of cluster 73 : 3290.514292006421
# intra varianz of cluster 74 : 3291.619023140314
# extra varianz of cluster 74 : 3290.4914975421048
# intra varianz of cluster 75 : 3285.8954480566963
# extra varianz of cluster 75 : 3290.518025374207
# intra varianz of cluster 76 : 3282.9655656401187
# extra varianz of cluster 76 : 3290.5137367972634
# intra varianz of cluster 77 : 3287.0217293257233
# extra varianz of cluster 77 : 3290.5293988377584
# intra varianz of cluster 78 : 3275.1136696813005
# extra varianz of cluster 78 : 3290.517787153554
# intra varianz of cluster 79 : 3290.447317397997
# extra varianz of cluster 79 : 3290.5086585133918
# intra varianz of cluster 80 : 3240.2287543836155
# extra varianz of cluster 80 : 3290.5081259477424
# intra varianz of cluster 81 : 3275.7529348925323
# extra varianz of cluster 81 : 3290.509394163508
# intra varianz of cluster 82 : 3290.842874172116
# extra varianz of cluster 82 : 3290.498999458685
# intra varianz of cluster 83 : 3290.184489773378
# extra varianz of cluster 83 : 3290.5117049904734
# intra varianz of cluster 84 : 3282.072599932557
# extra varianz of cluster 84 : 3290.5220679008385
# intra varianz of cluster 85 : 3291.840805501961
# extra varianz of cluster 85 : 3290.500547998163
# intra varianz of cluster 86 : 3317.058271396308
# extra varianz of cluster 86 : 3290.5073566247174
# intra varianz of cluster 87 : 3290.4864571108433
# extra varianz of cluster 87 : 3290.5080517218153
# intra varianz of cluster 88 : 3288.7790840429925
# extra varianz of cluster 88 : 3290.515699276252
# intra varianz of cluster 89 : 3292.554918932539
# extra varianz of cluster 89 : 3290.4760866218885
# intra varianz of cluster 90 : 3288.351296893556
# extra varianz of cluster 90 : 3290.5247442470168
# intra varianz of cluster 91 : 3290.9903257548926
# extra varianz of cluster 91 : 3290.497233710489
# intra varianz of cluster 92 : 3280.273640869147
# extra varianz of cluster 92 : 3290.5188940195662
# intra varianz of cluster 93 : 3291.1513279368282
# extra varianz of cluster 93 : 3290.502608596073
# intra varianz of cluster 94 : 3290.4023230132157
# extra varianz of cluster 94 : 3290.5099767953657
# intra varianz of cluster 95 : 3292.4889942556547
# extra varianz of cluster 95 : 3290.4998638884745
# intra varianz of cluster 96 : 3299.75501900125
# extra varianz of cluster 96 : 3290.5059571248175
# intra varianz of cluster 97 : 3288.6085482806616
# extra varianz of cluster 97 : 3290.513205380609
# intra varianz of cluster 98 : 3290.6182844897744
# extra varianz of cluster 98 : 3290.5041541561905
# intra varianz of cluster 99 : 3283.315832733176
# extra varianz of cluster 99 : 3290.50920636813

# %%
dif.argsort()
# Out:
# array([43, 86, 59, 41, 96, 15, 42, 28, 49, 23, 24, 89, 95, 60, 70, 48, 13,
#         0, 85, 14, 54, 65, 74, 50, 21, 53, 55, 68, 63, 46, 93, 67,  1, 91,
#        36, 29, 82,  8, 57, 31, 18, 56, 27,  5, 64, 98, 44, 52, 87, 35, 79,
#        34, 94, 83,  7, 58, 72, 69, 40, 88, 19, 47, 73, 97, 90, 20, 26,  2,
#        38, 11, 10, 17, 77, 62, 39, 30, 61, 75, 66, 33,  9, 99, 16, 76,  4,
#         6, 51, 84, 71, 22, 32, 92, 45, 37,  3, 81, 78, 12, 25, 80],
#       dtype=int64)
